# %%
import pandas as pd
import numpy as np
import sklearn as sk
import os
import torch
import copy
from torch.utils.data import Dataset, DataLoader

from sklearn.feature_extraction import DictVectorizer
from sklearn.externals import joblib
from sklearn.model_selection import ParameterGrid


from functools import reduce
from util import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
data_path = '../data'
data_dict = joblib.load(os.path.join(data_path, 'data_dict.pkl'))
exp_name = 'exp2'

# %%
# Key = starting state, value = next state
transition_dict_train = dict(zip(data_dict['train']['state_id'], data_dict['train']['next_state_id']))
transition_dict_val = dict(zip(data_dict['val']['state_id'], data_dict['val']['next_state_id']))

# %%
# Define the tuning grid
param_options = {
                  'state_dim' : [data_dict['train']['X'].shape[1]],
                  'action_dim' : [25],
                  'gamma' : [0.9],
                  'batch_size' : [512],
                  'lr' : [1e-4],
                  'num_epochs' : [300],
                  'hidden_dim' : [128, 256, 512, 1024],
                  'num_hidden' : [1, 2, 3, 5, 10],
                  'drop_prob' : [0.0],
                  'target_update': [10],
                  'option' : ['linear'],
                  'use_scheduler' : [False]
         }

config_grid = ParameterGrid(param_options)

# %%
# Train all the models
for config in config_grid:
    
    # Create a Dataset
    train_dataset = RL_Dataset(data_dict['train']['X'], 
                               data_dict['train']['action'],
                               data_dict['train']['reward'],
                               transition_dict_train)

    val_dataset = RL_Dataset(data_dict['val']['X'], 
                               data_dict['val']['action'],
                               data_dict['val']['reward'],
                               transition_dict_val)
    # Create a dataloader
    train_loader = DataLoader(train_dataset, 
                            config['batch_size'],
                            shuffle = True,
                            num_workers = 32
                             )

    val_loader = DataLoader(val_dataset, 
                             config['batch_size'],
                             shuffle = True,
                             num_workers = 32
                             )

    loaders = {'train' : train_loader,
               'val' : val_loader
              }

    dset_sizes = {'train' : len(train_dataset),
                  'val' : len(val_dataset)
                 }
    
    
    
    print(config)
    model = dueling_net(D_in = config['state_dim'], 
                        H = config['hidden_dim'], 
                        D_out = config['action_dim'],
                        drop_prob = config['drop_prob'],
                        num_hidden = config['num_hidden'],
                        option = config['option']
                       )

    target_model = dueling_net(D_in = config['state_dim'], 
                                H = config['hidden_dim'], 
                                D_out = config['action_dim'],
                                drop_prob = config['drop_prob'],
                                num_hidden = config['num_hidden'],
                                option = config['option']
                              )

    optimizer = optim.Adam([{'params': model.parameters()}], 
                            lr = config['lr'])

    if config['use_scheduler']:
        scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode = 'min', verbose = True)
    else:
        scheduler = None

    def weights_init(m):
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform(m.weight.data).float()

    model.apply(weights_init)
    target_model.apply(weights_init)

    if use_gpu:
        model = model.cuda()
        target_model.cuda()

    criterion = torch.nn.SmoothL1Loss(size_average = False)

    performance_dict, best_model, best_loss, time_elapsed = train_model_double(model = model, 
                                                                                target_model = target_model,
                                                                                loaders = loaders, 
                                                                                dset_sizes = dset_sizes, 
                                                                                config = config, 
                                                                                criterion = criterion,
                                                                                optimizer = optimizer,
                                                                                scheduler = scheduler,
                                                                                use_gpu = use_gpu)
    
    config_str = reduce(lambda x, y: x + y + '_', [str(key) + '_' + str(value) for key, value in config.items()]) + 'time_'+ str(time.time()).split('.')[1]
    checkpoints_path = os.path.join('../checkpoints/' + exp_name, config_str + '.chk')
    torch.save(best_model.state_dict(), checkpoints_path)
    
    performance_df = dict_to_df(performance_dict)
    config_df = pd.DataFrame(config, index = [0])
    config_df['config_str'] = config_str
    performance_df['config_str'] = config_str
    performance_df = performance_df.set_index('config_str').join(config_df.set_index('config_str'))
    performance_df.to_csv(os.path.join('../performance/' + exp_name, 'performance_' + config_str + '.csv'), index = True)
# Out:
# {'num_hidden': 1, 'target_update': 10, 'option': 'linear', 'drop_prob': 0.0, 'state_dim': 46, 'use_scheduler': False, 'batch_size': 512, 'lr': 0.0001, 'hidden_dim': 128, 'num_epochs': 300, 'gamma': 0.9, 'action_dim': 25}
# ----------
# Epoch 0/299
# ----------
# Updating Target Model
# train Loss: 1.494470, Best Value: 1.170697, Empirical Value: 0.128475
# val Loss: 1.647179, Best Value: 1.163967, Empirical Value: 0.206467
# Best Value updated
# ----------
# Epoch 1/299
# ----------
# train Loss: 1.372761, Best Value: 1.531943, Empirical Value: 0.821209
# val Loss: 1.269305, Best Value: 1.650092, Empirical Value: 1.058347
# Best Value updated
# ----------
# Epoch 2/299
# ----------
# train Loss: 1.296321, Best Value: 1.653908, Empirical Value: 1.077189
# val Loss: 1.262995, Best Value: 1.628762, Empirical Value: 1.072010
# ----------
# Epoch 3/299
# ----------
# train Loss: 1.293526, Best Value: 1.614934, Empirical Value: 1.072405
# val Loss: 1.261844, Best Value: 1.590778, Empirical Value: 1.061712
# ----------
# Epoch 4/299
# ----------
# train Loss: 1.293827, Best Value: 1.576939, Empirical Value: 1.059243
# val Loss: 1.263415, Best Value: 1.525232, Empirical Value: 1.028286
# ----------
# Epoch 5/299
# ----------
# train Loss: 1.294786, Best Value: 1.541248, Empirical Value: 1.041316
# val Loss: 1.265714, Best Value: 1.466873, Empirical Value: 0.998089
# ----------
# Epoch 6/299
# ----------
# train Loss: 1.295957, Best Value: 1.509116, Empirical Value: 1.023417
# val Loss: 1.266213, Best Value: 1.497569, Empirical Value: 1.017405
# ----------
# Epoch 7/299
# ----------
# train Loss: 1.297251, Best Value: 1.479289, Empirical Value: 1.003549
# val Loss: 1.268624, Best Value: 1.461859, Empirical Value: 0.998526
# ----------
# Epoch 8/299
# ----------
# train Loss: 1.299362, Best Value: 1.453387, Empirical Value: 0.985353
# val Loss: 1.269625, Best Value: 1.443742, Empirical Value: 0.973962
# ----------
# Epoch 9/299
# ----------
# train Loss: 1.300702, Best Value: 1.428651, Empirical Value: 0.965059
# val Loss: 1.271233, Best Value: 1.393133, Empirical Value: 0.951577
# ----------
# Epoch 10/299
# ----------
# Updating Target Model
# train Loss: 1.302415, Best Value: 1.407223, Empirical Value: 0.947391
# val Loss: 1.293119, Best Value: 1.377142, Empirical Value: 0.933681
# ----------
# Epoch 11/299
# ----------
# train Loss: 1.256898, Best Value: 1.628102, Empirical Value: 1.273765
# val Loss: 1.222766, Best Value: 1.608929, Empirical Value: 1.275963
# ----------
# Epoch 12/299
# ----------
# train Loss: 1.251737, Best Value: 1.653392, Empirical Value: 1.304500
# val Loss: 1.221840, Best Value: 1.670275, Empirical Value: 1.319796
# Best Value updated
# ----------
# Epoch 13/299
# ----------
# train Loss: 1.250732, Best Value: 1.652144, Empirical Value: 1.302360
# val Loss: 1.221240, Best Value: 1.657488, Empirical Value: 1.313061
# ----------
# Epoch 14/299
# ----------
# train Loss: 1.249988, Best Value: 1.649741, Empirical Value: 1.301283
# val Loss: 1.220410, Best Value: 1.625351, Empirical Value: 1.288256
# ----------
# Epoch 15/299
# ----------
# train Loss: 1.249483, Best Value: 1.646509, Empirical Value: 1.299007
# val Loss: 1.220388, Best Value: 1.640819, Empirical Value: 1.295561
# ----------
# Epoch 16/299
# ----------
# train Loss: 1.249317, Best Value: 1.642870, Empirical Value: 1.295670
# val Loss: 1.220100, Best Value: 1.612063, Empirical Value: 1.272079
# ----------
# Epoch 17/299
# ----------
# train Loss: 1.249035, Best Value: 1.636831, Empirical Value: 1.291918
# val Loss: 1.220063, Best Value: 1.615843, Empirical Value: 1.286810
# ----------
# Epoch 18/299
# ----------
# train Loss: 1.249215, Best Value: 1.634100, Empirical Value: 1.289652
# val Loss: 1.220065, Best Value: 1.622160, Empirical Value: 1.280995
# ----------
# Epoch 19/299
# ----------
# train Loss: 1.249000, Best Value: 1.631210, Empirical Value: 1.286856
# val Loss: 1.220135, Best Value: 1.608677, Empirical Value: 1.267972
# ----------
# Epoch 20/299
# ----------
# Updating Target Model
# train Loss: 1.249163, Best Value: 1.625759, Empirical Value: 1.282929
# val Loss: 1.235769, Best Value: 1.620913, Empirical Value: 1.272132
# ----------
# Epoch 21/299
# ----------
# train Loss: 1.233095, Best Value: 1.793675, Empirical Value: 1.513231
# val Loss: 1.203581, Best Value: 1.787807, Empirical Value: 1.518843
# Best Value updated
# ----------
# Epoch 22/299
# ----------
# train Loss: 1.230544, Best Value: 1.812084, Empirical Value: 1.528781
# val Loss: 1.202140, Best Value: 1.800258, Empirical Value: 1.512230
# Best Value updated
# ----------
# Epoch 23/299
# ----------
# train Loss: 1.229876, Best Value: 1.811891, Empirical Value: 1.526634
# val Loss: 1.202268, Best Value: 1.776619, Empirical Value: 1.497561
# ----------
# Epoch 24/299
# ----------
# train Loss: 1.229360, Best Value: 1.814180, Empirical Value: 1.528030
# val Loss: 1.201440, Best Value: 1.800544, Empirical Value: 1.515497
# Best Value updated
# ----------
# Epoch 25/299
# ----------
# train Loss: 1.229022, Best Value: 1.813687, Empirical Value: 1.525552
# val Loss: 1.201125, Best Value: 1.805353, Empirical Value: 1.525040
# Best Value updated
# ----------
# Epoch 26/299
# ----------
# train Loss: 1.228734, Best Value: 1.812812, Empirical Value: 1.525379
# val Loss: 1.201407, Best Value: 1.784785, Empirical Value: 1.513774
# ----------
# Epoch 27/299
# ----------
# train Loss: 1.228657, Best Value: 1.813328, Empirical Value: 1.525414
# val Loss: 1.201137, Best Value: 1.808188, Empirical Value: 1.518087
# Best Value updated
# ----------
# Epoch 28/299
# ----------
# train Loss: 1.228617, Best Value: 1.811952, Empirical Value: 1.522725
# val Loss: 1.201153, Best Value: 1.801430, Empirical Value: 1.516680
# ----------
# Epoch 29/299
# ----------
# train Loss: 1.228465, Best Value: 1.810784, Empirical Value: 1.521398
# val Loss: 1.202273, Best Value: 1.780861, Empirical Value: 1.507643
# ----------
# Epoch 30/299
# ----------
# Updating Target Model
# train Loss: 1.228521, Best Value: 1.808252, Empirical Value: 1.519787
# val Loss: 1.201257, Best Value: 1.812568, Empirical Value: 1.527469
# Best Value updated
# ----------
# Epoch 31/299
# ----------
# train Loss: 1.214291, Best Value: 1.943798, Empirical Value: 1.695245
# val Loss: 1.186819, Best Value: 1.951537, Empirical Value: 1.702582
# Best Value updated
# ----------
# Epoch 32/299
# ----------
# train Loss: 1.213107, Best Value: 1.956981, Empirical Value: 1.703697
# val Loss: 1.186316, Best Value: 1.923324, Empirical Value: 1.681629
# ----------
# Epoch 33/299
# ----------
# train Loss: 1.212581, Best Value: 1.960368, Empirical Value: 1.704240
# val Loss: 1.185963, Best Value: 1.945664, Empirical Value: 1.688962
# ----------
# Epoch 34/299
# ----------
# train Loss: 1.212255, Best Value: 1.962627, Empirical Value: 1.702410
# val Loss: 1.185720, Best Value: 1.971499, Empirical Value: 1.709102
# Best Value updated
# ----------
# Epoch 35/299
# ----------
# train Loss: 1.212188, Best Value: 1.965023, Empirical Value: 1.703340
# val Loss: 1.185827, Best Value: 1.975937, Empirical Value: 1.717466
# Best Value updated
# ----------
# Epoch 36/299
# ----------
# train Loss: 1.212090, Best Value: 1.964333, Empirical Value: 1.702076
# val Loss: 1.185318, Best Value: 1.956730, Empirical Value: 1.693704
# ----------
# Epoch 37/299
# ----------
# train Loss: 1.211987, Best Value: 1.964952, Empirical Value: 1.701488
# val Loss: 1.185349, Best Value: 1.940517, Empirical Value: 1.676920
# ----------
# Epoch 38/299
# ----------
# train Loss: 1.211960, Best Value: 1.965534, Empirical Value: 1.700275
# val Loss: 1.185235, Best Value: 1.970383, Empirical Value: 1.701579
# ----------
# Epoch 39/299
# ----------
# train Loss: 1.211917, Best Value: 1.965124, Empirical Value: 1.698338
# val Loss: 1.185430, Best Value: 1.948085, Empirical Value: 1.690891
# ----------
# Epoch 40/299
# ----------
# Updating Target Model
# train Loss: 1.211783, Best Value: 1.966141, Empirical Value: 1.699257
# val Loss: 1.184187, Best Value: 1.959951, Empirical Value: 1.687926
# ----------
# Epoch 41/299
# ----------
# train Loss: 1.200645, Best Value: 2.069853, Empirical Value: 1.831126
# val Loss: 1.173896, Best Value: 2.073016, Empirical Value: 1.834745
# Best Value updated
# ----------
# Epoch 42/299
# ----------
# train Loss: 1.199668, Best Value: 2.080829, Empirical Value: 1.836947
# val Loss: 1.174268, Best Value: 2.071027, Empirical Value: 1.833883
# ----------
# Epoch 43/299
# ----------
# train Loss: 1.198995, Best Value: 2.085697, Empirical Value: 1.837710
# val Loss: 1.172996, Best Value: 2.095048, Empirical Value: 1.836855
# Best Value updated
# ----------
# Epoch 44/299
# ----------
# train Loss: 1.198855, Best Value: 2.087402, Empirical Value: 1.836700
# val Loss: 1.173769, Best Value: 2.123041, Empirical Value: 1.868088
# Best Value updated
# ----------
# Epoch 45/299
# ----------
# train Loss: 1.198677, Best Value: 2.090237, Empirical Value: 1.837201
# val Loss: 1.172456, Best Value: 2.085285, Empirical Value: 1.830157
# ----------
# Epoch 46/299
# ----------
# train Loss: 1.198579, Best Value: 2.090169, Empirical Value: 1.836372
# val Loss: 1.172303, Best Value: 2.087485, Empirical Value: 1.836897
# ----------
# Epoch 47/299
# ----------
# train Loss: 1.198586, Best Value: 2.092585, Empirical Value: 1.835814
# val Loss: 1.172307, Best Value: 2.090358, Empirical Value: 1.836995
# ----------
# Epoch 48/299
# ----------
# train Loss: 1.198635, Best Value: 2.092160, Empirical Value: 1.835385
# val Loss: 1.172849, Best Value: 2.075443, Empirical Value: 1.823377
# ----------
# Epoch 49/299
# ----------
# train Loss: 1.198500, Best Value: 2.092285, Empirical Value: 1.834775
# val Loss: 1.172319, Best Value: 2.093178, Empirical Value: 1.828826
# ----------
# Epoch 50/299
# ----------
# Updating Target Model
# train Loss: 1.198471, Best Value: 2.092701, Empirical Value: 1.833564
# val Loss: 1.169248, Best Value: 2.091244, Empirical Value: 1.834498
# ----------
# Epoch 51/299
# ----------
# train Loss: 1.188415, Best Value: 2.186637, Empirical Value: 1.951911
# val Loss: 1.161812, Best Value: 2.190732, Empirical Value: 1.953285
# Best Value updated
# ----------
# Epoch 52/299
# ----------
# train Loss: 1.187569, Best Value: 2.196656, Empirical Value: 1.957037
# val Loss: 1.161920, Best Value: 2.168300, Empirical Value: 1.935378
# ----------
# Epoch 53/299
# ----------
# train Loss: 1.187153, Best Value: 2.200413, Empirical Value: 1.956984
# val Loss: 1.161276, Best Value: 2.204163, Empirical Value: 1.961346
# Best Value updated
# ----------
# Epoch 54/299
# ----------
# train Loss: 1.187006, Best Value: 2.203779, Empirical Value: 1.957022
# val Loss: 1.162008, Best Value: 2.151169, Empirical Value: 1.912783
# ----------
# Epoch 55/299
# ----------
# train Loss: 1.187025, Best Value: 2.206398, Empirical Value: 1.957753
# val Loss: 1.164818, Best Value: 2.194926, Empirical Value: 1.959213
# ----------
# Epoch 56/299
# ----------
# train Loss: 1.186844, Best Value: 2.205561, Empirical Value: 1.954820
# val Loss: 1.160816, Best Value: 2.200116, Empirical Value: 1.956929
# ----------
# Epoch 57/299
# ----------
# train Loss: 1.186694, Best Value: 2.209598, Empirical Value: 1.957060
# val Loss: 1.160803, Best Value: 2.203254, Empirical Value: 1.953320
# ----------
# Epoch 58/299
# ----------
# train Loss: 1.186615, Best Value: 2.208404, Empirical Value: 1.955077
# val Loss: 1.163692, Best Value: 2.190341, Empirical Value: 1.953696
# ----------
# Epoch 59/299
# ----------
# train Loss: 1.186485, Best Value: 2.210857, Empirical Value: 1.955839
# val Loss: 1.160782, Best Value: 2.198316, Empirical Value: 1.951402
# ----------
# Epoch 60/299
# ----------
# Updating Target Model
# train Loss: 1.186665, Best Value: 2.211782, Empirical Value: 1.955416
# val Loss: 1.159241, Best Value: 2.219639, Empirical Value: 1.954921
# Best Value updated
# ----------
# Epoch 61/299
# ----------
# train Loss: 1.178825, Best Value: 2.298798, Empirical Value: 2.067139
# val Loss: 1.152587, Best Value: 2.295121, Empirical Value: 2.062813
# Best Value updated
# ----------
# Epoch 62/299
# ----------
# train Loss: 1.178292, Best Value: 2.309810, Empirical Value: 2.073169
# val Loss: 1.152399, Best Value: 2.316530, Empirical Value: 2.071150
# Best Value updated
# ----------
# Epoch 63/299
# ----------
# train Loss: 1.177955, Best Value: 2.312747, Empirical Value: 2.071362
# val Loss: 1.152400, Best Value: 2.324043, Empirical Value: 2.082189
# Best Value updated
# ----------
# Epoch 64/299
# ----------
# train Loss: 1.177641, Best Value: 2.316409, Empirical Value: 2.073583
# val Loss: 1.152064, Best Value: 2.319426, Empirical Value: 2.076599
# ----------
# Epoch 65/299
# ----------
# train Loss: 1.177738, Best Value: 2.317707, Empirical Value: 2.071666
# val Loss: 1.151910, Best Value: 2.296215, Empirical Value: 2.051179
# ----------
# Epoch 66/299
# ----------
# train Loss: 1.177715, Best Value: 2.320754, Empirical Value: 2.072329
# val Loss: 1.151841, Best Value: 2.328988, Empirical Value: 2.070947
# Best Value updated
# ----------
# Epoch 67/299
# ----------
# train Loss: 1.177473, Best Value: 2.321056, Empirical Value: 2.071515
# val Loss: 1.151657, Best Value: 2.320168, Empirical Value: 2.070395
# ----------
# Epoch 68/299
# ----------
# train Loss: 1.177345, Best Value: 2.323915, Empirical Value: 2.071709
# val Loss: 1.151710, Best Value: 2.302924, Empirical Value: 2.057177
# ----------
# Epoch 69/299
# ----------
# train Loss: 1.177216, Best Value: 2.324122, Empirical Value: 2.071726
# val Loss: 1.151683, Best Value: 2.308771, Empirical Value: 2.055330
# ----------
# Epoch 70/299
# ----------
# Updating Target Model
# train Loss: 1.177380, Best Value: 2.324685, Empirical Value: 2.070518
# val Loss: 1.148494, Best Value: 2.304614, Empirical Value: 2.059249
# ----------
# Epoch 71/299
# ----------
# train Loss: 1.170501, Best Value: 2.385986, Empirical Value: 2.147481
# val Loss: 1.144868, Best Value: 2.385756, Empirical Value: 2.144440
# Best Value updated
# ----------
# Epoch 72/299
# ----------
# train Loss: 1.170426, Best Value: 2.393643, Empirical Value: 2.149554
# val Loss: 1.144365, Best Value: 2.377176, Empirical Value: 2.138729
# ----------
# Epoch 73/299
# ----------
# train Loss: 1.170118, Best Value: 2.396351, Empirical Value: 2.149725
# val Loss: 1.144477, Best Value: 2.392457, Empirical Value: 2.149581
# Best Value updated
# ----------
# Epoch 74/299
# ----------
# train Loss: 1.170057, Best Value: 2.398760, Empirical Value: 2.149779
# val Loss: 1.144150, Best Value: 2.383836, Empirical Value: 2.139204
# ----------
# Epoch 75/299
# ----------
# train Loss: 1.169812, Best Value: 2.399752, Empirical Value: 2.150349
# val Loss: 1.144914, Best Value: 2.425120, Empirical Value: 2.172178
# Best Value updated
# ----------
# Epoch 76/299
# ----------
# train Loss: 1.169860, Best Value: 2.400667, Empirical Value: 2.149526
# val Loss: 1.144199, Best Value: 2.407474, Empirical Value: 2.155240
# ----------
# Epoch 77/299
# ----------
# train Loss: 1.169867, Best Value: 2.402105, Empirical Value: 2.149323
# val Loss: 1.144371, Best Value: 2.416969, Empirical Value: 2.160078
# ----------
# Epoch 78/299
# ----------
# train Loss: 1.169778, Best Value: 2.403574, Empirical Value: 2.149470
# val Loss: 1.144056, Best Value: 2.385652, Empirical Value: 2.135653
# ----------
# Epoch 79/299
# ----------
# train Loss: 1.169902, Best Value: 2.403777, Empirical Value: 2.149064
# val Loss: 1.144555, Best Value: 2.368033, Empirical Value: 2.115394
# ----------
# Epoch 80/299
# ----------
# Updating Target Model
# train Loss: 1.169708, Best Value: 2.406330, Empirical Value: 2.148720
# val Loss: 1.141198, Best Value: 2.418116, Empirical Value: 2.159849
# ----------
# Epoch 81/299
# ----------
# train Loss: 1.163415, Best Value: 2.479449, Empirical Value: 2.247227
# val Loss: 1.137587, Best Value: 2.467267, Empirical Value: 2.233449
# Best Value updated
# ----------
# Epoch 82/299
# ----------
# train Loss: 1.162992, Best Value: 2.489818, Empirical Value: 2.251539
# val Loss: 1.137278, Best Value: 2.492030, Empirical Value: 2.251055
# Best Value updated
# ----------
# Epoch 83/299
# ----------
# train Loss: 1.162792, Best Value: 2.493069, Empirical Value: 2.251014
# val Loss: 1.138099, Best Value: 2.471222, Empirical Value: 2.237500
# ----------
# Epoch 84/299
# ----------
# train Loss: 1.162656, Best Value: 2.494630, Empirical Value: 2.251711
# val Loss: 1.137067, Best Value: 2.480065, Empirical Value: 2.239493
# ----------
# Epoch 85/299
# ----------
# train Loss: 1.162793, Best Value: 2.497509, Empirical Value: 2.252348
# val Loss: 1.137251, Best Value: 2.516140, Empirical Value: 2.271013
# Best Value updated
# ----------
# Epoch 86/299
# ----------
# train Loss: 1.162640, Best Value: 2.498504, Empirical Value: 2.251197
# val Loss: 1.137229, Best Value: 2.515925, Empirical Value: 2.263971
# ----------
# Epoch 87/299
# ----------
# train Loss: 1.162478, Best Value: 2.499294, Empirical Value: 2.251408
# val Loss: 1.137000, Best Value: 2.498813, Empirical Value: 2.248466
# ----------
# Epoch 88/299
# ----------
# train Loss: 1.162487, Best Value: 2.501445, Empirical Value: 2.252052
# val Loss: 1.136973, Best Value: 2.491952, Empirical Value: 2.237709
# ----------
# Epoch 89/299
# ----------
# train Loss: 1.162611, Best Value: 2.500773, Empirical Value: 2.250619
# val Loss: 1.136830, Best Value: 2.496461, Empirical Value: 2.248963
# ----------
# Epoch 90/299
# ----------
# Updating Target Model
# train Loss: 1.162360, Best Value: 2.501523, Empirical Value: 2.251131
# val Loss: 1.134381, Best Value: 2.480602, Empirical Value: 2.244254
# ----------
# Epoch 91/299
# ----------
# train Loss: 1.158946, Best Value: 2.536925, Empirical Value: 2.293152
# val Loss: 1.133197, Best Value: 2.551185, Empirical Value: 2.303364
# Best Value updated
# ----------
# Epoch 92/299
# ----------
# train Loss: 1.158725, Best Value: 2.540147, Empirical Value: 2.293577
# val Loss: 1.132972, Best Value: 2.540076, Empirical Value: 2.291936
# ----------
# Epoch 93/299
# ----------
# train Loss: 1.158364, Best Value: 2.543897, Empirical Value: 2.295058
# val Loss: 1.132935, Best Value: 2.525617, Empirical Value: 2.273232
# ----------
# Epoch 94/299
# ----------
# train Loss: 1.158210, Best Value: 2.544028, Empirical Value: 2.294110
# val Loss: 1.132959, Best Value: 2.528722, Empirical Value: 2.276877
# ----------
# Epoch 95/299
# ----------
# train Loss: 1.158247, Best Value: 2.547383, Empirical Value: 2.294822
# val Loss: 1.132855, Best Value: 2.535499, Empirical Value: 2.281537
# ----------
# Epoch 96/299
# ----------
# train Loss: 1.158282, Best Value: 2.546118, Empirical Value: 2.293070
# val Loss: 1.132991, Best Value: 2.545921, Empirical Value: 2.290597
# ----------
# Epoch 97/299
# ----------
# train Loss: 1.158054, Best Value: 2.548235, Empirical Value: 2.294383
# val Loss: 1.133240, Best Value: 2.563408, Empirical Value: 2.305216
# Best Value updated
# ----------
# Epoch 98/299
# ----------
# train Loss: 1.158204, Best Value: 2.547980, Empirical Value: 2.293633
# val Loss: 1.132918, Best Value: 2.550826, Empirical Value: 2.289331
# ----------
# Epoch 99/299
# ----------
# train Loss: 1.158254, Best Value: 2.548359, Empirical Value: 2.292960
# val Loss: 1.132802, Best Value: 2.547702, Empirical Value: 2.289194
# ----------
# Epoch 100/299
# ----------
# Updating Target Model
# train Loss: 1.158046, Best Value: 2.549358, Empirical Value: 2.294268
# val Loss: 1.130618, Best Value: 2.557094, Empirical Value: 2.292061
# ----------
# Epoch 101/299
# ----------
# train Loss: 1.152986, Best Value: 2.610101, Empirical Value: 2.371802
# val Loss: 1.127263, Best Value: 2.613999, Empirical Value: 2.369011
# Best Value updated
# ----------
# Epoch 102/299
# ----------
# train Loss: 1.152811, Best Value: 2.616313, Empirical Value: 2.374566
# val Loss: 1.127354, Best Value: 2.605598, Empirical Value: 2.362503
# ----------
# Epoch 103/299
# ----------
# train Loss: 1.152729, Best Value: 2.618639, Empirical Value: 2.375880
# val Loss: 1.127172, Best Value: 2.613470, Empirical Value: 2.366635
# ----------
# Epoch 104/299
# ----------
# train Loss: 1.152622, Best Value: 2.620123, Empirical Value: 2.374924
# val Loss: 1.127109, Best Value: 2.626018, Empirical Value: 2.378183
# Best Value updated
# ----------
# Epoch 105/299
# ----------
# train Loss: 1.152350, Best Value: 2.620031, Empirical Value: 2.375431
# val Loss: 1.127097, Best Value: 2.627721, Empirical Value: 2.372379
# Best Value updated
# ----------
# Epoch 106/299
# ----------
# train Loss: 1.152536, Best Value: 2.621728, Empirical Value: 2.374333
# val Loss: 1.127024, Best Value: 2.616908, Empirical Value: 2.368490
# ----------
# Epoch 107/299
# ----------
# train Loss: 1.152391, Best Value: 2.624470, Empirical Value: 2.374950
# val Loss: 1.126854, Best Value: 2.611625, Empirical Value: 2.361507
# ----------
# Epoch 108/299
# ----------
# train Loss: 1.152427, Best Value: 2.625184, Empirical Value: 2.374639
# val Loss: 1.127172, Best Value: 2.591969, Empirical Value: 2.350458
# ----------
# Epoch 109/299
# ----------
# train Loss: 1.152301, Best Value: 2.625114, Empirical Value: 2.375060
# val Loss: 1.127077, Best Value: 2.599992, Empirical Value: 2.355739
# ----------
# Epoch 110/299
# ----------
# Updating Target Model
# train Loss: 1.152308, Best Value: 2.624375, Empirical Value: 2.374495
# val Loss: 1.123876, Best Value: 2.625399, Empirical Value: 2.375936
# ----------
# Epoch 111/299
# ----------
# train Loss: 1.147661, Best Value: 2.675107, Empirical Value: 2.436839
# val Loss: 1.128855, Best Value: 2.715858, Empirical Value: 2.490506
# Best Value updated
# ----------
# Epoch 112/299
# ----------
# train Loss: 1.147549, Best Value: 2.680223, Empirical Value: 2.437602
# val Loss: 1.122833, Best Value: 2.632647, Empirical Value: 2.391629
# ----------
# Epoch 113/299
# ----------
# train Loss: 1.147472, Best Value: 2.681295, Empirical Value: 2.437849
# val Loss: 1.121901, Best Value: 2.654112, Empirical Value: 2.413280
# ----------
# Epoch 114/299
# ----------
# train Loss: 1.147335, Best Value: 2.682671, Empirical Value: 2.438236
# val Loss: 1.122627, Best Value: 2.642177, Empirical Value: 2.394103
# ----------
# Epoch 115/299
# ----------
# train Loss: 1.147263, Best Value: 2.682170, Empirical Value: 2.437626
# val Loss: 1.121829, Best Value: 2.679574, Empirical Value: 2.431575
# ----------
# Epoch 116/299
# ----------
# train Loss: 1.147162, Best Value: 2.684276, Empirical Value: 2.438656
# val Loss: 1.121765, Best Value: 2.679076, Empirical Value: 2.430018
# ----------
# Epoch 117/299
# ----------
# train Loss: 1.147215, Best Value: 2.686298, Empirical Value: 2.437419
# val Loss: 1.121840, Best Value: 2.699846, Empirical Value: 2.450072
# ----------
# Epoch 118/299
# ----------
# train Loss: 1.147140, Best Value: 2.686246, Empirical Value: 2.438020
# val Loss: 1.121700, Best Value: 2.693906, Empirical Value: 2.439543
# ----------
# Epoch 119/299
# ----------
# train Loss: 1.147107, Best Value: 2.686953, Empirical Value: 2.437364
# val Loss: 1.121688, Best Value: 2.671699, Empirical Value: 2.416976
# ----------
# Epoch 120/299
# ----------
# Updating Target Model
# train Loss: 1.147142, Best Value: 2.686859, Empirical Value: 2.437112
# val Loss: 1.119554, Best Value: 2.672650, Empirical Value: 2.425805
# ----------
# Epoch 121/299
# ----------
# train Loss: 1.143580, Best Value: 2.724668, Empirical Value: 2.480259
# val Loss: 1.118228, Best Value: 2.735369, Empirical Value: 2.482335
# Best Value updated
# ----------
# Epoch 122/299
# ----------
# train Loss: 1.143361, Best Value: 2.728454, Empirical Value: 2.481434
# val Loss: 1.117761, Best Value: 2.734411, Empirical Value: 2.477780
# ----------
# Epoch 123/299
# ----------
# train Loss: 1.143291, Best Value: 2.729992, Empirical Value: 2.481395
# val Loss: 1.117942, Best Value: 2.752897, Empirical Value: 2.498906
# Best Value updated
# ----------
# Epoch 124/299
# ----------
# train Loss: 1.143219, Best Value: 2.730893, Empirical Value: 2.480903
# val Loss: 1.117655, Best Value: 2.730303, Empirical Value: 2.475480
# ----------
# Epoch 125/299
# ----------
# train Loss: 1.143081, Best Value: 2.733399, Empirical Value: 2.482175
# val Loss: 1.117944, Best Value: 2.722887, Empirical Value: 2.473020
# ----------
# Epoch 126/299
# ----------
# train Loss: 1.143152, Best Value: 2.733032, Empirical Value: 2.480960
# val Loss: 1.117860, Best Value: 2.744422, Empirical Value: 2.489265
# ----------
# Epoch 127/299
# ----------
# train Loss: 1.142988, Best Value: 2.733956, Empirical Value: 2.481705
# val Loss: 1.118088, Best Value: 2.702504, Empirical Value: 2.455409
# ----------
# Epoch 128/299
# ----------
# train Loss: 1.142965, Best Value: 2.734435, Empirical Value: 2.481331
# val Loss: 1.117875, Best Value: 2.740755, Empirical Value: 2.488684
# ----------
# Epoch 129/299
# ----------
# train Loss: 1.142866, Best Value: 2.735159, Empirical Value: 2.481671
# val Loss: 1.117787, Best Value: 2.741295, Empirical Value: 2.486015
# ----------
# Epoch 130/299
# ----------
# Updating Target Model
# train Loss: 1.142963, Best Value: 2.736518, Empirical Value: 2.481213
# val Loss: 1.117383, Best Value: 2.701629, Empirical Value: 2.448303
# ----------
# Epoch 131/299
# ----------
# train Loss: 1.141110, Best Value: 2.757163, Empirical Value: 2.506924
# val Loss: 1.115570, Best Value: 2.766990, Empirical Value: 2.510983
# Best Value updated
# ----------
# Epoch 132/299
# ----------
# train Loss: 1.140850, Best Value: 2.759338, Empirical Value: 2.507943
# val Loss: 1.115676, Best Value: 2.764524, Empirical Value: 2.512439
# ----------
# Epoch 133/299
# ----------
# train Loss: 1.140897, Best Value: 2.760091, Empirical Value: 2.507814
# val Loss: 1.115721, Best Value: 2.775062, Empirical Value: 2.519401
# Best Value updated
# ----------
# Epoch 134/299
# ----------
# train Loss: 1.140740, Best Value: 2.762634, Empirical Value: 2.508447
# val Loss: 1.115550, Best Value: 2.762029, Empirical Value: 2.506689
# ----------
# Epoch 135/299
# ----------
# train Loss: 1.140646, Best Value: 2.762455, Empirical Value: 2.508026
# val Loss: 1.115846, Best Value: 2.750766, Empirical Value: 2.492542
# ----------
# Epoch 136/299
# ----------
# train Loss: 1.140705, Best Value: 2.764373, Empirical Value: 2.508018
# val Loss: 1.115649, Best Value: 2.758442, Empirical Value: 2.495822
# ----------
# Epoch 137/299
# ----------
# train Loss: 1.140613, Best Value: 2.763803, Empirical Value: 2.508035
# val Loss: 1.115564, Best Value: 2.770609, Empirical Value: 2.511970
# ----------
# Epoch 138/299
# ----------
# train Loss: 1.140533, Best Value: 2.763418, Empirical Value: 2.507538
# val Loss: 1.115481, Best Value: 2.749240, Empirical Value: 2.490921
# ----------
# Epoch 139/299
# ----------
# train Loss: 1.140557, Best Value: 2.765328, Empirical Value: 2.508432
# val Loss: 1.115840, Best Value: 2.754930, Empirical Value: 2.496724
# ----------
# Epoch 140/299
# ----------
# Updating Target Model
# train Loss: 1.140513, Best Value: 2.763784, Empirical Value: 2.507504
# val Loss: 1.113897, Best Value: 2.766772, Empirical Value: 2.507431
# ----------
# Epoch 141/299
# ----------
# train Loss: 1.137710, Best Value: 2.810100, Empirical Value: 2.565439
# val Loss: 1.114924, Best Value: 2.740139, Empirical Value: 2.497325
# ----------
# Epoch 142/299
# ----------
# train Loss: 1.137512, Best Value: 2.814755, Empirical Value: 2.567122
# val Loss: 1.112365, Best Value: 2.808427, Empirical Value: 2.561601
# Best Value updated
# ----------
# Epoch 143/299
# ----------
# train Loss: 1.137284, Best Value: 2.817942, Empirical Value: 2.567909
# val Loss: 1.112125, Best Value: 2.811228, Empirical Value: 2.561501
# Best Value updated
# ----------
# Epoch 144/299
# ----------
# train Loss: 1.137080, Best Value: 2.818450, Empirical Value: 2.567357
# val Loss: 1.112264, Best Value: 2.829671, Empirical Value: 2.574479
# Best Value updated
# ----------
# Epoch 145/299
# ----------
# train Loss: 1.137068, Best Value: 2.822898, Empirical Value: 2.568338
# val Loss: 1.112285, Best Value: 2.818937, Empirical Value: 2.559647
# ----------
# Epoch 146/299
# ----------
# train Loss: 1.137227, Best Value: 2.819872, Empirical Value: 2.566467
# val Loss: 1.112228, Best Value: 2.839104, Empirical Value: 2.578998
# Best Value updated
# ----------
# Epoch 147/299
# ----------
# train Loss: 1.137029, Best Value: 2.822402, Empirical Value: 2.567369
# val Loss: 1.112006, Best Value: 2.810342, Empirical Value: 2.548875
# ----------
# Epoch 148/299
# ----------
# train Loss: 1.137122, Best Value: 2.823626, Empirical Value: 2.567394
# val Loss: 1.112226, Best Value: 2.808405, Empirical Value: 2.542635
# ----------
# Epoch 149/299
# ----------
# train Loss: 1.136945, Best Value: 2.823821, Empirical Value: 2.566114
# val Loss: 1.112304, Best Value: 2.796051, Empirical Value: 2.542245
# ----------
# Epoch 150/299
# ----------
# Updating Target Model
# train Loss: 1.137152, Best Value: 2.825136, Empirical Value: 2.566846
# val Loss: 1.110399, Best Value: 2.815658, Empirical Value: 2.557422
# ----------
# Epoch 151/299
# ----------
# train Loss: 1.134105, Best Value: 2.860617, Empirical Value: 2.611606
# val Loss: 1.109086, Best Value: 2.877411, Empirical Value: 2.620465
# Best Value updated
# ----------
# Epoch 152/299
# ----------
# train Loss: 1.134110, Best Value: 2.865286, Empirical Value: 2.612774
# val Loss: 1.109136, Best Value: 2.871667, Empirical Value: 2.615667
# ----------
# Epoch 153/299
# ----------
# train Loss: 1.133910, Best Value: 2.865740, Empirical Value: 2.611744
# val Loss: 1.109000, Best Value: 2.872556, Empirical Value: 2.616973
# ----------
# Epoch 154/299
# ----------
# train Loss: 1.133845, Best Value: 2.868943, Empirical Value: 2.613623
# val Loss: 1.109082, Best Value: 2.892613, Empirical Value: 2.629734
# Best Value updated
# ----------
# Epoch 155/299
# ----------
# train Loss: 1.134002, Best Value: 2.867840, Empirical Value: 2.611786
# val Loss: 1.108858, Best Value: 2.871160, Empirical Value: 2.608873
# ----------
# Epoch 156/299
# ----------
# train Loss: 1.133844, Best Value: 2.871394, Empirical Value: 2.612334
# val Loss: 1.109679, Best Value: 2.851499, Empirical Value: 2.604370
# ----------
# Epoch 157/299
# ----------
# train Loss: 1.133858, Best Value: 2.870694, Empirical Value: 2.612216
# val Loss: 1.108809, Best Value: 2.869192, Empirical Value: 2.613367
# ----------
# Epoch 158/299
# ----------
# train Loss: 1.133778, Best Value: 2.871392, Empirical Value: 2.612882
# val Loss: 1.108760, Best Value: 2.870158, Empirical Value: 2.610646
# ----------
# Epoch 159/299
# ----------
# train Loss: 1.133831, Best Value: 2.873083, Empirical Value: 2.612226
# val Loss: 1.108905, Best Value: 2.885440, Empirical Value: 2.626662
# ----------
# Epoch 160/299
# ----------
# Updating Target Model
# train Loss: 1.133827, Best Value: 2.874433, Empirical Value: 2.611467
# val Loss: 1.108050, Best Value: 2.849332, Empirical Value: 2.588359
# ----------
# Epoch 161/299
# ----------
# train Loss: 1.131750, Best Value: 2.898090, Empirical Value: 2.641762
# val Loss: 1.106618, Best Value: 2.898113, Empirical Value: 2.632996
# Best Value updated
# ----------
# Epoch 162/299
# ----------
# train Loss: 1.131552, Best Value: 2.900548, Empirical Value: 2.641682
# val Loss: 1.106475, Best Value: 2.903569, Empirical Value: 2.646857
# Best Value updated
# ----------
# Epoch 163/299
# ----------
# train Loss: 1.131455, Best Value: 2.902252, Empirical Value: 2.643172
# val Loss: 1.106556, Best Value: 2.882530, Empirical Value: 2.620955
# ----------
# Epoch 164/299
# ----------
# train Loss: 1.131297, Best Value: 2.903671, Empirical Value: 2.642110
# val Loss: 1.106345, Best Value: 2.903067, Empirical Value: 2.634713
# ----------
# Epoch 165/299
# ----------
# train Loss: 1.131443, Best Value: 2.905068, Empirical Value: 2.643495
# val Loss: 1.106610, Best Value: 2.893329, Empirical Value: 2.622102
# ----------
# Epoch 166/299
# ----------
# train Loss: 1.131314, Best Value: 2.905758, Empirical Value: 2.641910
# val Loss: 1.106613, Best Value: 2.890223, Empirical Value: 2.626384
# ----------
# Epoch 167/299
# ----------
# train Loss: 1.131178, Best Value: 2.904864, Empirical Value: 2.641730
# val Loss: 1.106360, Best Value: 2.912772, Empirical Value: 2.647047
# Best Value updated
# ----------
# Epoch 168/299
# ----------
# train Loss: 1.131206, Best Value: 2.907978, Empirical Value: 2.642513
# val Loss: 1.106553, Best Value: 2.901433, Empirical Value: 2.637242
# ----------
# Epoch 169/299
# ----------
# train Loss: 1.131219, Best Value: 2.908493, Empirical Value: 2.641745
# val Loss: 1.107047, Best Value: 2.935346, Empirical Value: 2.668391
# Best Value updated
# ----------
# Epoch 170/299
# ----------
# Updating Target Model
# train Loss: 1.131189, Best Value: 2.908456, Empirical Value: 2.642775
# val Loss: 1.105537, Best Value: 2.904145, Empirical Value: 2.632886
# ----------
# Epoch 171/299
# ----------
# train Loss: 1.128934, Best Value: 2.945414, Empirical Value: 2.689552
# val Loss: 1.103412, Best Value: 2.964914, Empirical Value: 2.701797
# Best Value updated
# ----------
# Epoch 172/299
# ----------
# train Loss: 1.128672, Best Value: 2.952054, Empirical Value: 2.692081
# val Loss: 1.103463, Best Value: 2.955013, Empirical Value: 2.693093
# ----------
# Epoch 173/299
# ----------
# train Loss: 1.128564, Best Value: 2.953194, Empirical Value: 2.691656
# val Loss: 1.103898, Best Value: 2.943399, Empirical Value: 2.669651
# ----------
# Epoch 174/299
# ----------
# train Loss: 1.128520, Best Value: 2.955381, Empirical Value: 2.690841
# val Loss: 1.103678, Best Value: 2.965633, Empirical Value: 2.697596
# Best Value updated
# ----------
# Epoch 175/299
# ----------
# train Loss: 1.128387, Best Value: 2.953689, Empirical Value: 2.691527
# val Loss: 1.103998, Best Value: 2.993540, Empirical Value: 2.721731
# Best Value updated
# ----------
# Epoch 176/299
# ----------
# train Loss: 1.128333, Best Value: 2.957212, Empirical Value: 2.691711
# val Loss: 1.103751, Best Value: 2.972713, Empirical Value: 2.702381
# ----------
# Epoch 177/299
# ----------
# train Loss: 1.128357, Best Value: 2.957915, Empirical Value: 2.690766
# val Loss: 1.103502, Best Value: 2.961749, Empirical Value: 2.690917
# ----------
# Epoch 178/299
# ----------
# train Loss: 1.128270, Best Value: 2.958707, Empirical Value: 2.691226
# val Loss: 1.103760, Best Value: 2.983186, Empirical Value: 2.713838
# ----------
# Epoch 179/299
# ----------
# train Loss: 1.128278, Best Value: 2.960747, Empirical Value: 2.691091
# val Loss: 1.103508, Best Value: 2.976375, Empirical Value: 2.703130
# ----------
# Epoch 180/299
# ----------
# Updating Target Model
# train Loss: 1.128275, Best Value: 2.961240, Empirical Value: 2.690852
# val Loss: 1.101660, Best Value: 2.958008, Empirical Value: 2.690761
# ----------
# Epoch 181/299
# ----------
# train Loss: 1.125122, Best Value: 2.998584, Empirical Value: 2.739537
# val Loss: 1.100184, Best Value: 3.012910, Empirical Value: 2.751223
# Best Value updated
# ----------
# Epoch 182/299
# ----------
# train Loss: 1.124913, Best Value: 3.002277, Empirical Value: 2.740789
# val Loss: 1.113884, Best Value: 3.060300, Empirical Value: 2.800910
# Best Value updated
# ----------
# Epoch 183/299
# ----------
# train Loss: 1.124873, Best Value: 3.003879, Empirical Value: 2.739116
# val Loss: 1.100226, Best Value: 3.000764, Empirical Value: 2.733714
# ----------
# Epoch 184/299
# ----------
# train Loss: 1.124902, Best Value: 3.006821, Empirical Value: 2.740510
# val Loss: 1.100058, Best Value: 2.998958, Empirical Value: 2.730454
# ----------
# Epoch 185/299
# ----------
# train Loss: 1.124809, Best Value: 3.008462, Empirical Value: 2.740647
# val Loss: 1.100109, Best Value: 2.995203, Empirical Value: 2.722014
# ----------
# Epoch 186/299
# ----------
# train Loss: 1.124775, Best Value: 3.008441, Empirical Value: 2.739391
# val Loss: 1.100162, Best Value: 3.016891, Empirical Value: 2.745532
# ----------
# Epoch 187/299
# ----------
# train Loss: 1.124574, Best Value: 3.012005, Empirical Value: 2.740644
# val Loss: 1.100094, Best Value: 3.022303, Empirical Value: 2.749311
# ----------
# Epoch 188/299
# ----------
# train Loss: 1.124661, Best Value: 3.011599, Empirical Value: 2.740054
# val Loss: 1.100350, Best Value: 3.009851, Empirical Value: 2.736244
# ----------
# Epoch 189/299
# ----------
# train Loss: 1.124541, Best Value: 3.011460, Empirical Value: 2.739656
# val Loss: 1.100546, Best Value: 2.989109, Empirical Value: 2.711318
# ----------
# Epoch 190/299
# ----------
# Updating Target Model
# train Loss: 1.124488, Best Value: 3.013209, Empirical Value: 2.739246
# val Loss: 1.099453, Best Value: 2.996129, Empirical Value: 2.723574
# ----------
# Epoch 191/299
# ----------
# train Loss: 1.122924, Best Value: 3.037980, Empirical Value: 2.772177
# val Loss: 1.097959, Best Value: 3.030800, Empirical Value: 2.760329
# ----------
# Epoch 192/299
# ----------
# train Loss: 1.122671, Best Value: 3.042687, Empirical Value: 2.773777
# val Loss: 1.098269, Best Value: 3.060607, Empirical Value: 2.788547
# Best Value updated
# ----------
# Epoch 193/299
# ----------
# train Loss: 1.122368, Best Value: 3.044110, Empirical Value: 2.772719
# val Loss: 1.099088, Best Value: 3.002337, Empirical Value: 2.734005
# ----------
# Epoch 194/299
# ----------
# train Loss: 1.122528, Best Value: 3.047704, Empirical Value: 2.773384
# val Loss: 1.097862, Best Value: 3.040296, Empirical Value: 2.766429
# ----------
# Epoch 195/299
# ----------
# train Loss: 1.122367, Best Value: 3.047749, Empirical Value: 2.772879
# val Loss: 1.098023, Best Value: 3.080653, Empirical Value: 2.802478
# Best Value updated
# ----------
# Epoch 196/299
# ----------
# train Loss: 1.122504, Best Value: 3.048930, Empirical Value: 2.772364
# val Loss: 1.097917, Best Value: 3.054449, Empirical Value: 2.772539
# ----------
# Epoch 197/299
# ----------
# train Loss: 1.122416, Best Value: 3.050492, Empirical Value: 2.773435
# val Loss: 1.097726, Best Value: 3.061003, Empirical Value: 2.780537
# ----------
# Epoch 198/299
# ----------
# train Loss: 1.122251, Best Value: 3.050755, Empirical Value: 2.772291
# val Loss: 1.098127, Best Value: 3.076064, Empirical Value: 2.799105
# ----------
# Epoch 199/299
# ----------
# train Loss: 1.122163, Best Value: 3.052387, Empirical Value: 2.772914
# val Loss: 1.098115, Best Value: 3.070141, Empirical Value: 2.793236
# ----------
# Epoch 200/299
# ----------
# Updating Target Model
# train Loss: 1.122339, Best Value: 3.051863, Empirical Value: 2.772630
# val Loss: 1.098862, Best Value: 3.023864, Empirical Value: 2.746692
# ----------
# Epoch 201/299
# ----------
# train Loss: 1.122111, Best Value: 3.073296, Empirical Value: 2.798932
# val Loss: 1.111137, Best Value: 3.143147, Empirical Value: 2.868154
# Best Value updated
# ----------
# Epoch 202/299
# ----------
# train Loss: 1.121838, Best Value: 3.074833, Empirical Value: 2.798018
# val Loss: 1.097059, Best Value: 3.071974, Empirical Value: 2.798275
# ----------
# Epoch 203/299
# ----------
# train Loss: 1.121607, Best Value: 3.076486, Empirical Value: 2.799948
# val Loss: 1.097989, Best Value: 3.048731, Empirical Value: 2.781462
# ----------
# Epoch 204/299
# ----------
# train Loss: 1.121738, Best Value: 3.076051, Empirical Value: 2.798293
# val Loss: 1.096902, Best Value: 3.068623, Empirical Value: 2.795369
# ----------
# Epoch 205/299
# ----------
# train Loss: 1.121705, Best Value: 3.078292, Empirical Value: 2.799801
# val Loss: 1.097182, Best Value: 3.082874, Empirical Value: 2.801979
# ----------
# Epoch 206/299
# ----------
# train Loss: 1.121717, Best Value: 3.079814, Empirical Value: 2.799338
# val Loss: 1.097219, Best Value: 3.090116, Empirical Value: 2.807550
# ----------
# Epoch 207/299
# ----------
# train Loss: 1.121367, Best Value: 3.080825, Empirical Value: 2.799810
# val Loss: 1.097002, Best Value: 3.075105, Empirical Value: 2.790821
# ----------
# Epoch 208/299
# ----------
# train Loss: 1.121395, Best Value: 3.081114, Empirical Value: 2.797493
# val Loss: 1.096953, Best Value: 3.074962, Empirical Value: 2.792505
# ----------
# Epoch 209/299
# ----------
# train Loss: 1.121366, Best Value: 3.082850, Empirical Value: 2.800133
# val Loss: 1.097012, Best Value: 3.074728, Empirical Value: 2.787813
# ----------
# Epoch 210/299
# ----------
# Updating Target Model
# train Loss: 1.121398, Best Value: 3.082987, Empirical Value: 2.798204
# val Loss: 1.096834, Best Value: 3.065373, Empirical Value: 2.781063
# ----------
# Epoch 211/299
# ----------
# train Loss: 1.119630, Best Value: 3.111463, Empirical Value: 2.834104
# val Loss: 1.095118, Best Value: 3.107383, Empirical Value: 2.826919
# ----------
# Epoch 212/299
# ----------
# train Loss: 1.119604, Best Value: 3.114782, Empirical Value: 2.836623
# val Loss: 1.094908, Best Value: 3.097032, Empirical Value: 2.815005
# ----------
# Epoch 213/299
# ----------
# train Loss: 1.119510, Best Value: 3.118056, Empirical Value: 2.836606
# val Loss: 1.095530, Best Value: 3.092580, Empirical Value: 2.805361
# ----------
# Epoch 214/299
# ----------
# train Loss: 1.119419, Best Value: 3.116501, Empirical Value: 2.835223
# val Loss: 1.094756, Best Value: 3.129108, Empirical Value: 2.846865
# ----------
# Epoch 215/299
# ----------
# train Loss: 1.119294, Best Value: 3.120949, Empirical Value: 2.836019
# val Loss: 1.094930, Best Value: 3.123419, Empirical Value: 2.847878
# ----------
# Epoch 216/299
# ----------
# train Loss: 1.119039, Best Value: 3.119245, Empirical Value: 2.835027
# val Loss: 1.094800, Best Value: 3.129077, Empirical Value: 2.846357
# ----------
# Epoch 217/299
# ----------
# train Loss: 1.119307, Best Value: 3.121978, Empirical Value: 2.836627
# val Loss: 1.094806, Best Value: 3.118812, Empirical Value: 2.829657
# ----------
# Epoch 218/299
# ----------
# train Loss: 1.119190, Best Value: 3.122827, Empirical Value: 2.835524
# val Loss: 1.094806, Best Value: 3.126108, Empirical Value: 2.831531
# ----------
# Epoch 219/299
# ----------
# train Loss: 1.119281, Best Value: 3.123532, Empirical Value: 2.835357
# val Loss: 1.095029, Best Value: 3.112931, Empirical Value: 2.819772
# ----------
# Epoch 220/299
# ----------
# Updating Target Model
# train Loss: 1.119132, Best Value: 3.124470, Empirical Value: 2.834427
# val Loss: 1.093963, Best Value: 3.128895, Empirical Value: 2.842691
# ----------
# Epoch 221/299
# ----------
# train Loss: 1.117025, Best Value: 3.167272, Empirical Value: 2.891359
# val Loss: 1.092731, Best Value: 3.147886, Empirical Value: 2.871967
# Best Value updated
# ----------
# Epoch 222/299
# ----------
# train Loss: 1.116729, Best Value: 3.172754, Empirical Value: 2.893856
# val Loss: 1.092727, Best Value: 3.156578, Empirical Value: 2.872907
# Best Value updated
# ----------
# Epoch 223/299
# ----------
# train Loss: 1.116719, Best Value: 3.173805, Empirical Value: 2.892129
# val Loss: 1.092562, Best Value: 3.174754, Empirical Value: 2.894591
# Best Value updated
# ----------
# Epoch 224/299
# ----------
# train Loss: 1.116561, Best Value: 3.176333, Empirical Value: 2.893340
# val Loss: 1.092137, Best Value: 3.182748, Empirical Value: 2.892235
# Best Value updated
# ----------
# Epoch 225/299
# ----------
# train Loss: 1.116671, Best Value: 3.177883, Empirical Value: 2.892664
# val Loss: 1.092718, Best Value: 3.207417, Empirical Value: 2.923146
# Best Value updated
# ----------
# Epoch 226/299
# ----------
# train Loss: 1.116498, Best Value: 3.176894, Empirical Value: 2.892075
# val Loss: 1.092091, Best Value: 3.186754, Empirical Value: 2.896736
# ----------
# Epoch 227/299
# ----------
# train Loss: 1.116493, Best Value: 3.181707, Empirical Value: 2.893072
# val Loss: 1.102589, Best Value: 3.222691, Empirical Value: 2.942216
# Best Value updated
# ----------
# Epoch 228/299
# ----------
# train Loss: 1.116044, Best Value: 3.183551, Empirical Value: 2.893081
# val Loss: 1.116382, Best Value: 3.253771, Empirical Value: 2.959702
# Best Value updated
# ----------
# Epoch 229/299
# ----------
# train Loss: 1.116395, Best Value: 3.183642, Empirical Value: 2.892112
# val Loss: 1.092356, Best Value: 3.173158, Empirical Value: 2.884297
# ----------
# Epoch 230/299
# ----------
# Updating Target Model
# train Loss: 1.116456, Best Value: 3.183557, Empirical Value: 2.892580
# val Loss: 1.092023, Best Value: 3.175390, Empirical Value: 2.880006
# ----------
# Epoch 231/299
# ----------
# train Loss: 1.114719, Best Value: 3.215061, Empirical Value: 2.932277
# val Loss: 1.091662, Best Value: 3.179316, Empirical Value: 2.897107
# ----------
# Epoch 232/299
# ----------
# train Loss: 1.114673, Best Value: 3.219515, Empirical Value: 2.934377
# val Loss: 1.090434, Best Value: 3.223034, Empirical Value: 2.938632
# ----------
# Epoch 233/299
# ----------
# train Loss: 1.114595, Best Value: 3.221324, Empirical Value: 2.933857
# val Loss: 1.090411, Best Value: 3.216961, Empirical Value: 2.928945
# ----------
# Epoch 234/299
# ----------
# train Loss: 1.114470, Best Value: 3.221922, Empirical Value: 2.933765
# val Loss: 1.090168, Best Value: 3.220875, Empirical Value: 2.937747
# ----------
# Epoch 235/299
# ----------
# train Loss: 1.114473, Best Value: 3.223938, Empirical Value: 2.935296
# val Loss: 1.096093, Best Value: 3.242568, Empirical Value: 2.952690
# ----------
# Epoch 236/299
# ----------
# train Loss: 1.114381, Best Value: 3.226738, Empirical Value: 2.933680
# val Loss: 1.090657, Best Value: 3.266500, Empirical Value: 2.971727
# Best Value updated
# ----------
# Epoch 237/299
# ----------
# train Loss: 1.114277, Best Value: 3.225227, Empirical Value: 2.933161
# val Loss: 1.090100, Best Value: 3.225853, Empirical Value: 2.930999
# ----------
# Epoch 238/299
# ----------
# train Loss: 1.114475, Best Value: 3.229575, Empirical Value: 2.934178
# val Loss: 1.090274, Best Value: 3.228727, Empirical Value: 2.931583
# ----------
# Epoch 239/299
# ----------
# train Loss: 1.114355, Best Value: 3.228879, Empirical Value: 2.933449
# val Loss: 1.090435, Best Value: 3.236675, Empirical Value: 2.945816
# ----------
# Epoch 240/299
# ----------
# Updating Target Model
# train Loss: 1.114254, Best Value: 3.231119, Empirical Value: 2.934404
# val Loss: 1.089756, Best Value: 3.240024, Empirical Value: 2.938311
# ----------
# Epoch 241/299
# ----------
# train Loss: 1.112340, Best Value: 3.271940, Empirical Value: 2.990087
# val Loss: 1.087899, Best Value: 3.288026, Empirical Value: 3.000351
# Best Value updated
# ----------
# Epoch 242/299
# ----------
# train Loss: 1.112049, Best Value: 3.275468, Empirical Value: 2.991373
# val Loss: 1.088253, Best Value: 3.265727, Empirical Value: 2.975553
# ----------
# Epoch 243/299
# ----------
# train Loss: 1.112268, Best Value: 3.278107, Empirical Value: 2.991566
# val Loss: 1.088017, Best Value: 3.282496, Empirical Value: 2.987894
# ----------
# Epoch 244/299
# ----------
# train Loss: 1.111982, Best Value: 3.280763, Empirical Value: 2.991829
# val Loss: 1.088600, Best Value: 3.252034, Empirical Value: 2.967830
# ----------
# Epoch 245/299
# ----------
# train Loss: 1.111779, Best Value: 3.282114, Empirical Value: 2.991125
# val Loss: 1.088053, Best Value: 3.287335, Empirical Value: 3.000814
# ----------
# Epoch 246/299
# ----------
# train Loss: 1.111807, Best Value: 3.284656, Empirical Value: 2.991895
# val Loss: 1.088006, Best Value: 3.276068, Empirical Value: 2.985917
# ----------
# Epoch 247/299
# ----------
# train Loss: 1.111941, Best Value: 3.283561, Empirical Value: 2.992415
# val Loss: 1.088039, Best Value: 3.269147, Empirical Value: 2.971422
# ----------
# Epoch 248/299
# ----------
# train Loss: 1.111773, Best Value: 3.285423, Empirical Value: 2.991025
# val Loss: 1.088023, Best Value: 3.288118, Empirical Value: 2.995991
# Best Value updated
# ----------
# Epoch 249/299
# ----------
# train Loss: 1.111666, Best Value: 3.288564, Empirical Value: 2.992222
# val Loss: 1.087993, Best Value: 3.302792, Empirical Value: 3.004571
# Best Value updated
# ----------
# Epoch 250/299
# ----------
# Updating Target Model
# train Loss: 1.111776, Best Value: 3.287984, Empirical Value: 2.990568
# val Loss: 1.086809, Best Value: 3.281249, Empirical Value: 2.988459
# ----------
# Epoch 251/299
# ----------
# train Loss: 1.110148, Best Value: 3.317301, Empirical Value: 3.027090
# val Loss: 1.086049, Best Value: 3.325969, Empirical Value: 3.034314
# Best Value updated
# ----------
# Epoch 252/299
# ----------
# train Loss: 1.109936, Best Value: 3.323562, Empirical Value: 3.027964
# val Loss: 1.086397, Best Value: 3.292946, Empirical Value: 2.999726
# ----------
# Epoch 253/299
# ----------
# train Loss: 1.109961, Best Value: 3.323576, Empirical Value: 3.029071
# val Loss: 1.086140, Best Value: 3.341073, Empirical Value: 3.048119
# Best Value updated
# ----------
# Epoch 254/299
# ----------
# train Loss: 1.109831, Best Value: 3.325981, Empirical Value: 3.028218
# val Loss: 1.086098, Best Value: 3.340299, Empirical Value: 3.039766
# ----------
# Epoch 255/299
# ----------
# train Loss: 1.109876, Best Value: 3.328454, Empirical Value: 3.028818
# val Loss: 1.085895, Best Value: 3.330302, Empirical Value: 3.027836
# ----------
# Epoch 256/299
# ----------
# train Loss: 1.109841, Best Value: 3.328750, Empirical Value: 3.027700
# val Loss: 1.086399, Best Value: 3.332870, Empirical Value: 3.032360
# ----------
# Epoch 257/299
# ----------
# train Loss: 1.109809, Best Value: 3.330002, Empirical Value: 3.027695
# val Loss: 1.085767, Best Value: 3.349189, Empirical Value: 3.038746
# Best Value updated
# ----------
# Epoch 258/299
# ----------
# train Loss: 1.109927, Best Value: 3.331590, Empirical Value: 3.029287
# val Loss: 1.097111, Best Value: 3.383976, Empirical Value: 3.083352
# Best Value updated
# ----------
# Epoch 259/299
# ----------
# train Loss: 1.109876, Best Value: 3.331636, Empirical Value: 3.026974
# val Loss: 1.085561, Best Value: 3.337673, Empirical Value: 3.035944
# ----------
# Epoch 260/299
# ----------
# Updating Target Model
# train Loss: 1.109620, Best Value: 3.332190, Empirical Value: 3.027894
# val Loss: 1.084836, Best Value: 3.343609, Empirical Value: 3.039287
# ----------
# Epoch 261/299
# ----------
# train Loss: 1.107730, Best Value: 3.373154, Empirical Value: 3.082607
# val Loss: 1.084724, Best Value: 3.364693, Empirical Value: 3.081672
# ----------
# Epoch 262/299
# ----------
# train Loss: 1.107685, Best Value: 3.379140, Empirical Value: 3.085219
# val Loss: 1.083409, Best Value: 3.384082, Empirical Value: 3.086514
# Best Value updated
# ----------
# Epoch 263/299
# ----------
# train Loss: 1.107523, Best Value: 3.379608, Empirical Value: 3.083918
# ...
# ----------
# Epoch 213/299
# ----------
# train Loss: 0.559055, Best Value: 12.502006, Empirical Value: 11.058616
# val Loss: 1.036546, Best Value: 12.616416, Empirical Value: 11.230903
# ----------
# Epoch 214/299
# ----------
# train Loss: 0.553358, Best Value: 12.500728, Empirical Value: 11.051607
# val Loss: 1.075634, Best Value: 12.581186, Empirical Value: 11.214755
# ----------
# Epoch 215/299
# ----------
# train Loss: 0.551841, Best Value: 12.506182, Empirical Value: 11.051789
# val Loss: 1.067720, Best Value: 12.605680, Empirical Value: 11.195295
# ----------
# Epoch 216/299
# ----------
# train Loss: 0.544515, Best Value: 12.493801, Empirical Value: 11.039253
# val Loss: 1.072310, Best Value: 12.586220, Empirical Value: 11.169504
# ----------
# Epoch 217/299
# ----------
# train Loss: 0.542072, Best Value: 12.500025, Empirical Value: 11.039435
# val Loss: 1.064878, Best Value: 12.586152, Empirical Value: 11.143298
# ----------
# Epoch 218/299
# ----------
# train Loss: 0.538747, Best Value: 12.505722, Empirical Value: 11.031741
# val Loss: 1.068905, Best Value: 12.726738, Empirical Value: 11.257651
# Best Value updated
# ----------
# Epoch 219/299
# ----------
# train Loss: 0.534354, Best Value: 12.508176, Empirical Value: 11.030340
# val Loss: 1.060352, Best Value: 12.639787, Empirical Value: 11.178081
# ----------
# Epoch 220/299
# ----------
# Updating Target Model
# train Loss: 0.534056, Best Value: 12.521837, Empirical Value: 11.027673
# val Loss: 0.940395, Best Value: 12.758645, Empirical Value: 11.338888
# Best Value updated
# ----------
# Epoch 221/299
# ----------
# train Loss: 0.566418, Best Value: 12.684685, Empirical Value: 11.305840
# val Loss: 0.993451, Best Value: 12.782929, Empirical Value: 11.436288
# Best Value updated
# ----------
# Epoch 222/299
# ----------
# train Loss: 0.549893, Best Value: 12.665285, Empirical Value: 11.270966
# val Loss: 1.021614, Best Value: 12.775114, Empirical Value: 11.410850
# ----------
# Epoch 223/299
# ----------
# train Loss: 0.540753, Best Value: 12.672825, Empirical Value: 11.264537
# val Loss: 1.013388, Best Value: 12.696303, Empirical Value: 11.316391
# ----------
# Epoch 224/299
# ----------
# train Loss: 0.530250, Best Value: 12.694533, Empirical Value: 11.261705
# val Loss: 1.017957, Best Value: 12.851855, Empirical Value: 11.444695
# Best Value updated
# ----------
# Epoch 225/299
# ----------
# train Loss: 0.526717, Best Value: 12.676164, Empirical Value: 11.252857
# val Loss: 1.027142, Best Value: 12.819808, Empirical Value: 11.417360
# ----------
# Epoch 226/299
# ----------
# train Loss: 0.523196, Best Value: 12.687728, Empirical Value: 11.242038
# val Loss: 1.036308, Best Value: 12.834248, Empirical Value: 11.420745
# ----------
# Epoch 227/299
# ----------
# train Loss: 0.519340, Best Value: 12.685165, Empirical Value: 11.237970
# val Loss: 1.036294, Best Value: 12.798274, Empirical Value: 11.402962
# ----------
# Epoch 228/299
# ----------
# train Loss: 0.515402, Best Value: 12.684456, Empirical Value: 11.238094
# val Loss: 1.050045, Best Value: 12.709861, Empirical Value: 11.278068
# ----------
# Epoch 229/299
# ----------
# train Loss: 0.509877, Best Value: 12.696565, Empirical Value: 11.237798
# val Loss: 1.027641, Best Value: 12.867945, Empirical Value: 11.431102
# Best Value updated
# ----------
# Epoch 230/299
# ----------
# Updating Target Model
# train Loss: 0.508518, Best Value: 12.703627, Empirical Value: 11.235214
# val Loss: 0.926643, Best Value: 12.755560, Empirical Value: 11.324208
# ----------
# Epoch 231/299
# ----------
# train Loss: 0.529794, Best Value: 12.775895, Empirical Value: 11.347148
# val Loss: 1.001425, Best Value: 12.952036, Empirical Value: 11.533409
# Best Value updated
# ----------
# Epoch 232/299
# ----------
# train Loss: 0.517797, Best Value: 12.762984, Empirical Value: 11.312075
# val Loss: 0.993922, Best Value: 12.808055, Empirical Value: 11.385541
# ----------
# Epoch 233/299
# ----------
# train Loss: 0.511881, Best Value: 12.764764, Empirical Value: 11.302538
# val Loss: 1.004457, Best Value: 12.815074, Empirical Value: 11.373426
# ----------
# Epoch 234/299
# ----------
# train Loss: 0.504442, Best Value: 12.756760, Empirical Value: 11.295944
# val Loss: 1.016108, Best Value: 12.848932, Empirical Value: 11.404461
# ----------
# Epoch 235/299
# ----------
# train Loss: 0.498390, Best Value: 12.768552, Empirical Value: 11.298106
# val Loss: 1.021559, Best Value: 12.914334, Empirical Value: 11.492766
# ----------
# Epoch 236/299
# ----------
# train Loss: 0.492802, Best Value: 12.758163, Empirical Value: 11.289502
# val Loss: 1.021759, Best Value: 12.799569, Empirical Value: 11.389036
# ----------
# Epoch 237/299
# ----------
# train Loss: 0.488632, Best Value: 12.757747, Empirical Value: 11.283390
# val Loss: 1.018596, Best Value: 12.929641, Empirical Value: 11.474549
# ----------
# Epoch 238/299
# ----------
# train Loss: 0.483956, Best Value: 12.769381, Empirical Value: 11.280209
# val Loss: 1.027177, Best Value: 12.917462, Empirical Value: 11.444722
# ----------
# Epoch 239/299
# ----------
# train Loss: 0.481733, Best Value: 12.767065, Empirical Value: 11.281385
# val Loss: 1.030726, Best Value: 12.836378, Empirical Value: 11.405668
# ----------
# Epoch 240/299
# ----------
# Updating Target Model
# train Loss: 0.481382, Best Value: 12.758097, Empirical Value: 11.271910
# val Loss: 0.945883, Best Value: 12.871841, Empirical Value: 11.432203
# ----------
# Epoch 241/299
# ----------
# train Loss: 0.512996, Best Value: 12.857244, Empirical Value: 11.435088
# val Loss: 1.012887, Best Value: 13.063636, Empirical Value: 11.658281
# Best Value updated
# ----------
# Epoch 242/299
# ----------
# train Loss: 0.506576, Best Value: 12.845361, Empirical Value: 11.401453
# val Loss: 1.014970, Best Value: 12.956290, Empirical Value: 11.537594
# ----------
# Epoch 243/299
# ----------
# train Loss: 0.493183, Best Value: 12.845423, Empirical Value: 11.391436
# val Loss: 1.010568, Best Value: 12.976715, Empirical Value: 11.544652
# ----------
# Epoch 244/299
# ----------
# train Loss: 0.487316, Best Value: 12.839559, Empirical Value: 11.384528
# val Loss: 1.025693, Best Value: 12.949981, Empirical Value: 11.531259
# ----------
# Epoch 245/299
# ----------
# train Loss: 0.481250, Best Value: 12.859005, Empirical Value: 11.386715
# val Loss: 1.029127, Best Value: 12.940691, Empirical Value: 11.541775
# ----------
# Epoch 246/299
# ----------
# train Loss: 0.478066, Best Value: 12.846549, Empirical Value: 11.381045
# val Loss: 1.031605, Best Value: 12.854095, Empirical Value: 11.440181
# ----------
# Epoch 247/299
# ----------
# train Loss: 0.472968, Best Value: 12.855690, Empirical Value: 11.376519
# val Loss: 1.026067, Best Value: 12.995553, Empirical Value: 11.558485
# ----------
# Epoch 248/299
# ----------
# train Loss: 0.468968, Best Value: 12.858961, Empirical Value: 11.375848
# val Loss: 1.009063, Best Value: 13.027038, Empirical Value: 11.565951
# ----------
# Epoch 249/299
# ----------
# train Loss: 0.463139, Best Value: 12.864266, Empirical Value: 11.369047
# val Loss: 1.021923, Best Value: 13.049478, Empirical Value: 11.547402
# ----------
# Epoch 250/299
# ----------
# Updating Target Model
# train Loss: 0.460521, Best Value: 12.858982, Empirical Value: 11.370117
# val Loss: 0.940362, Best Value: 12.966307, Empirical Value: 11.513769
# ----------
# Epoch 251/299
# ----------
# train Loss: 0.495800, Best Value: 12.905593, Empirical Value: 11.485396
# val Loss: 1.007176, Best Value: 12.999505, Empirical Value: 11.608824
# ----------
# Epoch 252/299
# ----------
# train Loss: 0.486771, Best Value: 12.879877, Empirical Value: 11.452846
# val Loss: 1.006404, Best Value: 12.957251, Empirical Value: 11.567274
# ----------
# Epoch 253/299
# ----------
# train Loss: 0.474046, Best Value: 12.884772, Empirical Value: 11.447277
# val Loss: 1.013942, Best Value: 13.000092, Empirical Value: 11.589397
# ----------
# Epoch 254/299
# ----------
# train Loss: 0.467418, Best Value: 12.892041, Empirical Value: 11.445494
# val Loss: 1.018711, Best Value: 12.973800, Empirical Value: 11.570579
# ----------
# Epoch 255/299
# ----------
# train Loss: 0.463561, Best Value: 12.902637, Empirical Value: 11.437326
# val Loss: 1.008891, Best Value: 13.019690, Empirical Value: 11.600991
# ----------
# Epoch 256/299
# ----------
# train Loss: 0.457347, Best Value: 12.895300, Empirical Value: 11.430951
# val Loss: 1.022492, Best Value: 13.057062, Empirical Value: 11.642091
# ----------
# Epoch 257/299
# ----------
# train Loss: 0.455700, Best Value: 12.901466, Empirical Value: 11.425003
# val Loss: 1.019441, Best Value: 13.046883, Empirical Value: 11.630247
# ----------
# Epoch 258/299
# ----------
# train Loss: 0.449394, Best Value: 12.902591, Empirical Value: 11.424370
# val Loss: 1.038758, Best Value: 13.009824, Empirical Value: 11.590462
# ----------
# Epoch 259/299
# ----------
# train Loss: 0.448208, Best Value: 12.906091, Empirical Value: 11.425346
# val Loss: 1.025198, Best Value: 13.072853, Empirical Value: 11.622047
# Best Value updated
# ----------
# Epoch 260/299
# ----------
# Updating Target Model
# train Loss: 0.444494, Best Value: 12.906180, Empirical Value: 11.416186
# val Loss: 0.944302, Best Value: 13.028013, Empirical Value: 11.595400
# ----------
# Epoch 261/299
# ----------
# train Loss: 0.482630, Best Value: 12.997482, Empirical Value: 11.551342
# val Loss: 0.994849, Best Value: 12.974580, Empirical Value: 11.559430
# ----------
# Epoch 262/299
# ----------
# train Loss: 0.472355, Best Value: 12.967231, Empirical Value: 11.515272
# val Loss: 0.999733, Best Value: 13.080650, Empirical Value: 11.707558
# Best Value updated
# ----------
# Epoch 263/299
# ----------
# train Loss: 0.461111, Best Value: 12.984644, Empirical Value: 11.510273
# val Loss: 1.004845, Best Value: 13.198513, Empirical Value: 11.765660
# Best Value updated
# ----------
# Epoch 264/299
# ----------
# train Loss: 0.452547, Best Value: 12.988057, Empirical Value: 11.504278
# val Loss: 1.016978, Best Value: 13.139900, Empirical Value: 11.703971
# ----------
# Epoch 265/299
# ----------
# train Loss: 0.450544, Best Value: 12.967242, Empirical Value: 11.491259
# val Loss: 1.017995, Best Value: 13.167493, Empirical Value: 11.764647
# ----------
# Epoch 266/299
# ----------
# train Loss: 0.444152, Best Value: 12.965825, Empirical Value: 11.492183
# val Loss: 1.006136, Best Value: 13.089145, Empirical Value: 11.678643
# ----------
# Epoch 267/299
# ----------
# train Loss: 0.439859, Best Value: 12.956273, Empirical Value: 11.490027
# val Loss: 1.022022, Best Value: 13.024986, Empirical Value: 11.599292
# ----------
# Epoch 268/299
# ----------
# train Loss: 0.437211, Best Value: 12.955928, Empirical Value: 11.484075
# val Loss: 1.008370, Best Value: 13.053562, Empirical Value: 11.621738
# ----------
# Epoch 269/299
# ----------
# train Loss: 0.432874, Best Value: 12.964389, Empirical Value: 11.478414
# val Loss: 1.017192, Best Value: 13.124391, Empirical Value: 11.675311
# ----------
# Epoch 270/299
# ----------
# Updating Target Model
# train Loss: 0.430455, Best Value: 12.963816, Empirical Value: 11.473491
# val Loss: 0.929388, Best Value: 13.177841, Empirical Value: 11.754536
# ----------
# Epoch 271/299
# ----------
# train Loss: 0.462266, Best Value: 13.062333, Empirical Value: 11.651480
# val Loss: 0.990225, Best Value: 13.204338, Empirical Value: 11.841014
# Best Value updated
# ----------
# Epoch 272/299
# ----------
# train Loss: 0.452006, Best Value: 13.058350, Empirical Value: 11.617767
# val Loss: 0.993430, Best Value: 13.186152, Empirical Value: 11.792749
# ----------
# Epoch 273/299
# ----------
# train Loss: 0.440426, Best Value: 13.047894, Empirical Value: 11.611887
# val Loss: 1.019312, Best Value: 13.245247, Empirical Value: 11.873664
# Best Value updated
# ----------
# Epoch 274/299
# ----------
# train Loss: 0.434247, Best Value: 13.062381, Empirical Value: 11.605402
# val Loss: 0.999773, Best Value: 13.141456, Empirical Value: 11.748363
# ----------
# Epoch 275/299
# ----------
# train Loss: 0.427684, Best Value: 13.046416, Empirical Value: 11.601666
# val Loss: 0.998975, Best Value: 13.144092, Empirical Value: 11.714021
# ----------
# Epoch 276/299
# ----------
# train Loss: 0.423389, Best Value: 13.047946, Empirical Value: 11.596194
# val Loss: 1.008222, Best Value: 13.199274, Empirical Value: 11.765069
# ----------
# Epoch 277/299
# ----------
# train Loss: 0.420430, Best Value: 13.041193, Empirical Value: 11.584820
# val Loss: 1.025506, Best Value: 13.123984, Empirical Value: 11.760381
# ----------
# Epoch 278/299
# ----------
# train Loss: 0.416626, Best Value: 13.037542, Empirical Value: 11.589213
# val Loss: 1.016941, Best Value: 13.188055, Empirical Value: 11.746635
# ----------
# Epoch 279/299
# ----------
# train Loss: 0.412716, Best Value: 13.043329, Empirical Value: 11.584781
# val Loss: 1.019426, Best Value: 13.244795, Empirical Value: 11.854545
# ----------
# Epoch 280/299
# ----------
# Updating Target Model
# train Loss: 0.410351, Best Value: 13.045506, Empirical Value: 11.580599
# val Loss: 0.914424, Best Value: 13.217093, Empirical Value: 11.824304
# ----------
# Epoch 281/299
# ----------
# train Loss: 0.443348, Best Value: 13.093014, Empirical Value: 11.664839
# val Loss: 0.985407, Best Value: 13.239240, Empirical Value: 11.825643
# ----------
# Epoch 282/299
# ----------
# train Loss: 0.434160, Best Value: 13.079459, Empirical Value: 11.626024
# val Loss: 0.979303, Best Value: 13.202083, Empirical Value: 11.794004
# ----------
# Epoch 283/299
# ----------
# train Loss: 0.422171, Best Value: 13.063634, Empirical Value: 11.615897
# val Loss: 0.983365, Best Value: 13.175625, Empirical Value: 11.756302
# ----------
# Epoch 284/299
# ----------
# train Loss: 0.417324, Best Value: 13.059467, Empirical Value: 11.615498
# val Loss: 0.981805, Best Value: 13.187241, Empirical Value: 11.780258
# ----------
# Epoch 285/299
# ----------
# train Loss: 0.413011, Best Value: 13.066813, Empirical Value: 11.602217
# val Loss: 1.002277, Best Value: 13.264830, Empirical Value: 11.848206
# Best Value updated
# ----------
# Epoch 286/299
# ----------
# train Loss: 0.407675, Best Value: 13.073631, Empirical Value: 11.602654
# val Loss: 0.995388, Best Value: 13.286064, Empirical Value: 11.880463
# Best Value updated
# ----------
# Epoch 287/299
# ----------
# train Loss: 0.402613, Best Value: 13.067732, Empirical Value: 11.603825
# val Loss: 0.989051, Best Value: 13.134098, Empirical Value: 11.719443
# ----------
# Epoch 288/299
# ----------
# train Loss: 0.397577, Best Value: 13.061336, Empirical Value: 11.594636
# val Loss: 0.985107, Best Value: 13.265734, Empirical Value: 11.830671
# ----------
# Epoch 289/299
# ----------
# train Loss: 0.398458, Best Value: 13.072343, Empirical Value: 11.595191
# val Loss: 0.987418, Best Value: 13.270729, Empirical Value: 11.855707
# ----------
# Epoch 290/299
# ----------
# Updating Target Model
# train Loss: 0.393067, Best Value: 13.064492, Empirical Value: 11.587535
# val Loss: 0.903858, Best Value: 13.171425, Empirical Value: 11.807138
# ----------
# Epoch 291/299
# ----------
# train Loss: 0.423404, Best Value: 13.064154, Empirical Value: 11.626214
# val Loss: 0.969594, Best Value: 13.138437, Empirical Value: 11.747519
# ----------
# Epoch 292/299
# ----------
# train Loss: 0.414536, Best Value: 13.043014, Empirical Value: 11.593884
# val Loss: 0.999748, Best Value: 13.325058, Empirical Value: 11.928501
# Best Value updated
# ----------
# Epoch 293/299
# ----------
# train Loss: 0.405043, Best Value: 13.040455, Empirical Value: 11.584461
# val Loss: 0.980881, Best Value: 13.163325, Empirical Value: 11.766155
# ----------
# Epoch 294/299
# ----------
# train Loss: 0.399877, Best Value: 13.034782, Empirical Value: 11.572560
# val Loss: 0.990218, Best Value: 13.208776, Empirical Value: 11.780678
# ----------
# Epoch 295/299
# ----------
# train Loss: 0.394167, Best Value: 13.048892, Empirical Value: 11.571562
# val Loss: 0.986771, Best Value: 13.214817, Empirical Value: 11.798014
# ----------
# Epoch 296/299
# ----------
# train Loss: 0.391898, Best Value: 13.052578, Empirical Value: 11.566734
# val Loss: 0.985363, Best Value: 13.166882, Empirical Value: 11.772395
# ----------
# Epoch 297/299
# ----------
# train Loss: 0.385378, Best Value: 13.036611, Empirical Value: 11.560320
# val Loss: 1.006261, Best Value: 13.204751, Empirical Value: 11.765178
# ----------
# Epoch 298/299
# ----------
# train Loss: 0.382487, Best Value: 13.037570, Empirical Value: 11.558886
# val Loss: 0.996640, Best Value: 13.181534, Empirical Value: 11.793939
# ----------
# Epoch 299/299
# ----------
# train Loss: 0.381113, Best Value: 13.032981, Empirical Value: 11.558017
# val Loss: 1.001017, Best Value: 13.178879, Empirical Value: 11.770687
# Training complete in 41m 19s
# Best value: 13.325058
